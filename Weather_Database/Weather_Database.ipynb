# %%
#import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#zip the data sets to make coordinates
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
#import citipy module
from citipy import citipy

# %%
# Cities array.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
print(cities)
# Out:
# ['qabis', 'nikolskoye', 'batticaloa', 'labuhan', 'bengkulu', 'san andres', 'srednekolymsk', 'punta arenas', 'bluff', 'jamestown', 'taltal', 'meyungs', 'vicuna', 'coos bay', 'vaini', 'mrirt', 'bethel', 'hilo', 'mar del plata', 'touros', 'lebu', 'papetoai', 'shepsi', 'rikitea', 'ushuaia', 'lamar', 'ouro preto do oeste', 'new norfolk', 'dukat', 'warqla', 'lazaro cardenas', 'komsomolskiy', 'taolanaro', 'paamiut', 'saint-philippe', 'cape town', 'busselton', 'geraldton', 'soyo', 'mataura', 'carnarvon', 'port alfred', 'arraial do cabo', 'barrow', 'samur', 'mys shmidta', 'atuona', 'paita', 'xuddur', 'atbasar', 'bambous virieux', 'puerto ayora', 'bali', 'tumannyy', 'ponta do sol', 'dunedin', 'illoqqortoormiut', 'kurilsk', 'dingle', 'kargopol', 'alvarado', 'hasaki', 'portree', 'mahaicony', 'chicama', 'qaanaaq', 'albany', 'hervey bay', 'cherskiy', 'belushya guba', 'airai', 'east london', 'arman', 'merrill', 'salalah', 'longyearbyen', 'wesel', 'broken hill', 'ust-nera', 'newport', 'mount gambier', 'saskylakh', 'namatanai', 'cabo san lucas', 'cidreira', 'pingxiang', 'witu', 'werda', 'khatanga', 'pleasanton', 'ossora', 'kilemary', 'sitka', 'melfi', 'olga', 'hithadhoo', 'trairi', 'paris', 'hobart', 'svetlogorsk', 'constitucion', 'abha', 'ancud', 'yulara', 'presidencia roque saenz pena', 'cayenne', 'banda aceh', 'rongcheng', 'russkaya polyana', 'zheleznodorozhnyy', 'sabzevar', 'pangody', 'saint george', 'ihiala', 'sorvag', 'isangel', 'dingtao', 'grand river south east', 'tura', 'samusu', 'zavolzhsk', 'georgetown', 'severo-kurilsk', 'okha', 'kosh-agach', 'ust-tsilma', 'hastings', 'toamasina', 'marcona', 'eureka', 'nanortalik', 'griffith', 'calvinia', 'kahului', 'kumluca', 'balestrand', 'necochea', 'noumea', 'khandyga', 'kapaa', 'lusambo', 'port macquarie', 'sayat', 'la tuque', 'esperance', 'ketchenery', 'port elizabeth', 'talnakh', 'clarence town', 'oranjestad', 'adre', 'launceston', 'naze', 'opobo', 'jalu', 'klaksvik', 'upernavik', 'hay river', 'atar', 'rock sound', 'ahipara', 'hermanus', 'zaranj', 'edd', 'billings', 'apatou', 'provideniya', 'oskemen', 'kodiak', 'lorengau', 'boueni', 'saint anthony', 'husavik', 'nogliki', 'middelburg', 'suoyarvi', 'vardo', 'dikson', 'tacuarembo', 'shache', 'castro', 'sinnamary', 'pevek', 'daru', 'ibra', 'adrar', 'norman wells', 'bredasdorp', 'vila franca do campo', 'abong mbang', 'tasiilaq', 'bobonong', 'barentsburg', 'san quintin', 'america dourada', 'vostok', 'raton', 'nhulunbuy', 'sobolevo', 'souillac', 'high level', 'toktogul', 'waingapu', 'aklavik', 'tiksi', 'pathein', 'xinyu', 'faya', 'rivadavia', 'kakrala', 'lompoc', 'thompson', 'moroto', 'laurel', 'petrivka', 'sarai mir', 'tecoanapa', 'chapleau', 'balgazyn', 'mayo', 'saint-pierre', 'olavarria', 'lamu', 'eyl', 'hirado', 'zabid', 'rietavas', 'palabuhanratu', 'poum', 'goderich', 'aporawan', 'torbat-e jam', 'yellowknife', 'itaborai', 'riyadh', 'buritis', 'saint-augustin', 'mouzakion', 'berdigestyakh', 'ostrovnoy', 'bouza', 'pulupandan', 'clevelandia', 'kargasok', 'sentyabrskiy', 'meulaboh', 'ituni', 'bolungarvik', 'lucapa', 'codrington', 'khasan', 'port moresby', 'methoni', 'butaritari', 'sola', 'pilar', 'brae', 'santa fe', 'deputatskiy', 'guerrero negro', 'vestmannaeyjar', 'katherine', 'emba', 'berlevag', 'lolua', 'coihaique', 'takhtamygda', 'attawapiskat', 'victoria', 'nizhniy ingash', 'san policarpo', 'aden', 'kavieng', 'kamenskoye', 'ratnagiri', 'capaci', 'svetlyy', 'kathu', 'galt', 'rawson', 'santiago', 'victor harbor', 'arandis', 'narsaq', 'arlit', 'lakes entrance', 'lagoa', 'indapur', 'general pico', 'ribeira grande', 'karratha', 'dalbandin', 'cabra', 'paslek', 'kambove', 'north bend', 'walvis bay', 'acari', 'weatherford', 'senmonorom', 'half moon bay', 'lavrentiya', 'lunsar', 'beyneu', 'doctor pedro p. pena', 'matam', 'oranjemund', 'herat', 'havre-saint-pierre', 'samarai', 'pisco', 'san nicolas', 'sisimiut', 'iqaluit', 'vaitupu', 'kikwit', 'shelburne', 'chenghai', 'kabalo', 'tuatapere', 'ramsar', 'haifa', 'kaitangata', 'lagos', 'korla', 'caravelas ...

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#city weather data storage array
city_data=[]

#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1


    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
        "Country": city_country,
        "Lat": city_lat,
        "Lng": city_lng,
        "Max Temp": city_max_temp,
        "Humidity": city_humidity,
        "Cloudiness": city_clouds,
        "Wind Speed": city_wind,
        "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
      print("City not found. Skipping...")
      pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qabis
# City not found. Skipping...
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | batticaloa
# Processing Record 4 of Set 1 | labuhan
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | san andres
# Processing Record 7 of Set 1 | srednekolymsk
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | taltal
# Processing Record 12 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 1 | vicuna
# Processing Record 14 of Set 1 | coos bay
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 1 | bethel
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | touros
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | papetoai
# Processing Record 23 of Set 1 | shepsi
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | lamar
# Processing Record 27 of Set 1 | ouro preto do oeste
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | dukat
# Processing Record 30 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 1 | lazaro cardenas
# Processing Record 32 of Set 1 | komsomolskiy
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | paamiut
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | geraldton
# Processing Record 39 of Set 1 | soyo
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | samur
# Processing Record 46 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | paita
# Processing Record 49 of Set 1 | xuddur
# Processing Record 50 of Set 1 | atbasar
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | bali
# Processing Record 4 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | dunedin
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | kurilsk
# Processing Record 9 of Set 2 | dingle
# Processing Record 10 of Set 2 | kargopol
# Processing Record 11 of Set 2 | alvarado
# Processing Record 12 of Set 2 | hasaki
# Processing Record 13 of Set 2 | portree
# Processing Record 14 of Set 2 | mahaicony
# City not found. Skipping...
# Processing Record 15 of Set 2 | chicama
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | hervey bay
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | airai
# Processing Record 22 of Set 2 | east london
# Processing Record 23 of Set 2 | arman
# Processing Record 24 of Set 2 | merrill
# Processing Record 25 of Set 2 | salalah
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | wesel
# Processing Record 28 of Set 2 | broken hill
# Processing Record 29 of Set 2 | ust-nera
# Processing Record 30 of Set 2 | newport
# Processing Record 31 of Set 2 | mount gambier
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | namatanai
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | cidreira
# Processing Record 36 of Set 2 | pingxiang
# Processing Record 37 of Set 2 | witu
# Processing Record 38 of Set 2 | werda
# Processing Record 39 of Set 2 | khatanga
# Processing Record 40 of Set 2 | pleasanton
# Processing Record 41 of Set 2 | ossora
# Processing Record 42 of Set 2 | kilemary
# Processing Record 43 of Set 2 | sitka
# Processing Record 44 of Set 2 | melfi
# Processing Record 45 of Set 2 | olga
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | trairi
# Processing Record 48 of Set 2 | paris
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | svetlogorsk
# Processing Record 1 of Set 3 | constitucion
# Processing Record 2 of Set 3 | abha
# Processing Record 3 of Set 3 | ancud
# Processing Record 4 of Set 3 | yulara
# Processing Record 5 of Set 3 | presidencia roque saenz pena
# Processing Record 6 of Set 3 | cayenne
# Processing Record 7 of Set 3 | banda aceh
# Processing Record 8 of Set 3 | rongcheng
# Processing Record 9 of Set 3 | russkaya polyana
# Processing Record 10 of Set 3 | zheleznodorozhnyy
# Processing Record 11 of Set 3 | sabzevar
# Processing Record 12 of Set 3 | pangody
# Processing Record 13 of Set 3 | saint george
# Processing Record 14 of Set 3 | ihiala
# Processing Record 15 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 3 | isangel
# Processing Record 17 of Set 3 | dingtao
# Processing Record 18 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 3 | tura
# Processing Record 20 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 3 | zavolzhsk
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | severo-kurilsk
# Processing Record 24 of Set 3 | okha
# Processing Record 25 of Set 3 | kosh-agach
# Processing Record 26 of Set 3 | ust-tsilma
# Processing Record 27 of Set 3 | hastings
# Processing Record 28 of Set 3 | toamasina
# Processing Record 29 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 3 | eureka
# Processing Record 31 of Set 3 | nanortalik
# Processing Record 32 of Set 3 | griffith
# Processing Record 33 of Set 3 | calvinia
# Processing Record 34 of Set 3 | kahului
# Processing Record 35 of Set 3 | kumluca
# Processing Record 36 of Set 3 | balestrand
# Processing Record 37 of Set 3 | necochea
# Processing Record 38 of Set 3 | noumea
# Processing Record 39 of Set 3 | khandyga
# Processing Record 40 of Set 3 | kapaa
# Processing Record 41 of Set 3 | lusambo
# Processing Record 42 of Set 3 | port macquarie
# Processing Record 43 of Set 3 | sayat
# Processing Record 44 of Set 3 | la tuque
# Processing Record 45 of Set 3 | esperance
# Processing Record 46 of Set 3 | ketchenery
# City not found. Skipping...
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | talnakh
# Processing Record 49 of Set 3 | clarence town
# Processing Record 50 of Set 3 | oranjestad
# Processing Record 1 of Set 4 | adre
# Processing Record 2 of Set 4 | launceston
# Processing Record 3 of Set 4 | naze
# Processing Record 4 of Set 4 | opobo
# City not found. Skipping...
# Processing Record 5 of Set 4 | jalu
# Processing Record 6 of Set 4 | klaksvik
# Processing Record 7 of Set 4 | upernavik
# Processing Record 8 of Set 4 | hay river
# Processing Record 9 of Set 4 | atar
# Processing Record 10 of Set 4 | rock sound
# Processing Record 11 of Set 4 | ahipara
# Processing Record 12 of Set 4 | hermanus
# Processing Record 13 of Set 4 | zaranj
# Processing Record 14 of Set 4 | edd
# Processing Record 15 of Set 4 | billings
# Processing Record 16 of Set 4 | apatou
# Processing Record 17 of Set 4 | provideniya
# Processing Record 18 of Set 4 | oskemen
# Processing Record 19 of Set 4 | kodiak
# Processing Record 20 of Set 4 | lorengau
# Processing Record 21 of Set 4 | boueni
# Processing Record 22 of Set 4 | saint anthony
# Processing Record 23 of Set 4 | husavik
# Processing Record 24 of Set 4 | nogliki
# Processing Record 25 of Set 4 | middelburg
# Processing Record 26 of Set 4 | suoyarvi
# Processing Record 27 of Set 4 | vardo
# Processing Record 28 of Set 4 | dikson
# Processing Record 29 of Set 4 | tacuarembo
# Processing Record 30 of Set 4 | shache
# Processing Record 31 of Set 4 | castro
# Processing Record 32 of Set 4 | sinnamary
# Processing Record 33 of Set 4 | pevek
# Processing Record 34 of Set 4 | daru
# Processing Record 35 of Set 4 | ibra
# Processing Record 36 of Set 4 | adrar
# Processing Record 37 of Set 4 | norman wells
# Processing Record 38 of Set 4 | bredasdorp
# Processing Record 39 of Set 4 | vila franca do campo
# Processing Record 40 of Set 4 | abong mbang
# Processing Record 41 of Set 4 | tasiilaq
# Processing Record 42 of Set 4 | bobonong
# City not found. Skipping...
# Processing Record 43 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 4 | san quintin
# Processing Record 45 of Set 4 | america dourada
# Processing Record 46 of Set 4 | vostok
# Processing Record 47 of Set 4 | raton
# Processing Record 48 of Set 4 | nhulunbuy
# Processing Record 49 of Set 4 | sobolevo
# Processing Record 50 of Set 4 | souillac
# Processing Record 1 of Set 5 | high level
# Processing Record 2 of Set 5 | toktogul
# Processing Record 3 of Set 5 | waingapu
# Processing Record 4 of Set 5 | aklavik
# Processing Record 5 of Set 5 | tiksi
# Processing Record 6 of Set 5 | pathein
# Processing Record 7 of Set 5 | xinyu
# Processing Record 8 of Set 5 | faya
# Processing Record 9 of Set 5 | rivadavia
# Processing Record 10 of Set 5 | kakrala
# Processing Record 11 of Set 5 | lompoc
# Processing Record 12 of Set 5 | thompson
# Processing Record 13 of Set 5 | moroto
# Processing Record 14 of Set 5 | laurel
# Processing Record 15 of Set 5 | petrivka
# Processing Record 16 of Set 5 | sarai mir
# Processing Record 17 of Set 5 | tecoanapa
# Processing Record 18 of Set 5 | chapleau
# Processing Record 19 of Set 5 | balgazyn
# Processing Record 20 of Set 5 | mayo
# Processing Record 21 of Set 5 | saint-pierre
# Processing Record 22 of Set 5 | olavarria
# Processing Record 23 of Set 5 | lamu
# Processing Record 24 of Set 5 | eyl
# Processing Record 25 of Set 5 | hirado
# Processing Record 26 of Set 5 | zabid
# Processing Record 27 of Set 5 | rietavas
# Processing Record 28 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 5 | poum
# Processing Record 30 of Set 5 | goderich
# Processing Record 31 of Set 5 | aporawan
# City not found. Skipping...
# Processing Record 32 of Set 5 | torbat-e jam
# Processing Record 33 of Set 5 | yellowknife
# Processing Record 34 of Set 5 | itaborai
# Processing Record 35 of Set 5 | riyadh
# Processing Record 36 of Set 5 | buritis
# Processing Record 37 of Set 5 | saint-augustin
# Processing Record 38 of Set 5 | mouzakion
# City not found. Skipping...
# Processing Record 39 of Set 5 | berdigestyakh
# Processing Record 40 of Set 5 | ostrovnoy
# Processing Record 41 of Set 5 | bouza
# Processing Record 42 of Set 5 | pulupandan
# Processing Record 43 of Set 5 | clevelandia
# Processing Record 44 of Set 5 | kargasok
# Processing Record 45 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 5 | meulaboh
# Processing Record 47 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 48 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 5 | lucapa
# Processing Record 50 of Set 5 | codrington
# Processing Record 1 of Set 6 | khasan
# Processing Record 2 of Set 6 | port moresby
# Processing Record 3 of Set 6 | methoni
# Processing Record 4 of Set 6 | butaritari
# Processing Record 5 of Set 6 | sola
# Processing Record 6 of Set 6 | pilar
# Processing Record 7 of Set 6 | brae
# Processing Record 8 of Set 6 | santa fe
# Processing Record 9 of Set 6 | deputatskiy
# Processing Record 10 of Set 6 | guerrero negro
# Processing Record 11 of Set 6 | vestmannaeyjar
# Processing Record 12 of Set 6 | katherine
# Processing Record 13 of Set 6 | emba
# Processing Record 14 of Set 6 | berlevag
# Processing Record 15 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 6 | coihaique
# Processing Record 17 of Set 6 | takhtamygda
# Processing Record 18 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 6 | victoria
# Processing Record 20 of Set 6 | nizhniy ingash
# Processing Record 21 of Set 6 | san policarpo
# Processing Record 22 of Set 6 | aden
# Processing Record 23 of Set 6 | kavieng
# Processing Record 24 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 6 | ratnagiri
# Processing Record 26 of Set 6 | capaci
# Processing Record 27 of Set 6 | svetlyy
# Processing Record 28 of Set 6 | kathu
# Processing Record 29 of Set 6 | galt
# Processing Record 30 of Set 6 | rawson
# Processing Record 31 of Set 6 | santiago
# Processing Record 32 of Set 6 | victor harbor
# Processing Record 33 of Set 6 | arandis
# Processing Record 34 of Set 6 | narsaq
# Processing Record 35 of Set 6 | arlit
# Processing Record 36 of Set 6 | lakes entrance
# Processing Record 37 of Set 6 | lagoa
# Processing Record 38 of Set 6 | indapur
# Processing Record 39 of Set 6 | general pico
# Processing Record 40 of Set 6 | ribeira grande
# Processing Record 41 of Set 6 | karratha
# Processing Record 42 of Set 6 | dalbandin
# Processing Record 43 of Set 6 | cabra
# Processing Record 44 of Set 6 | paslek
# Processing Record 45 of Set 6 | kambove
# Processing Record 46 of Set 6 | north bend
# Processing Record 47 of Set 6 | walvis bay
# Processing Record 48 of Set 6 | acari
# Processing Record 49 of Set 6 | weatherford
# Processing Record 50 of Set 6 | senmonorom
# City not found. Skipping...
# Processing Record 1 of Set 7 | half moon bay
# Processing Record 2 of Set 7 | lavrentiya
# Processing Record 3 of Set 7 | lunsar
# Processing Record 4 of Set 7 | beyneu
# Processing Record 5 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 6 of Set 7 | matam
# Processing Record 7 of Set 7 | oranjemund
# Processing Record 8 of Set 7 | herat
# Processing Record 9 of Set 7 | havre-saint-pierre
# Processing Record 10 of Set 7 | samarai
# Processing Record 11 of Set 7 | pisco
# Processing Record 12 of Set 7 | san nicolas
# Processing Record 13 of Set 7 | sisimiut
# Processing Record 14 of Set 7 | iqaluit
# Processing Record 15 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 7 | kikwit
# Processing Record 17 of Set 7 | shelburne
# Processing Record 18 of Set 7 | chenghai
# Processing Record 19 of Set 7 | kabalo
# Processing Record 20 of Set 7 | tuatapere
# Processing Record 21 of Set 7 | ramsar
# Processing Record 22 of Set 7 | haifa
# Processing Record 23 of Set 7 | kaitangata
# Processing Record 24 of Set 7 | lagos
# Processing Record 25 of Set 7 | korla
# Processing Record 26 of Set 7 | caravelas
# Processing Record 27 of Set 7 | kruisfontein
# Processing Record 28 of Set 7 | lucea
# Processing Record 29 of Set 7 | verkh-usugli
# Processing Record 30 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 7 | qaqortoq
# Processing Record 32 of Set 7 | xining
# Processing Record 33 of Set 7 | moyale
# Processing Record 34 of Set 7 | verkhnetulomskiy
# Processing Record 35 of Set 7 | pochutla
# Processing Record 36 of Set 7 | peleduy
# Processing Record 37 of Set 7 | tahoua
# Processing Record 38 of Set 7 | duncan
# Processing Record 39 of Set 7 | camapua
# Processing Record 40 of Set 7 | russellville
# Processing Record 41 of Set 7 | dharchula
# Processing Record 42 of Set 7 | asaka
# Processing Record 43 of Set 7 | christchurch
# Processing Record 44 of Set 7 | khash
# Processing Record 45 of Set 7 | birsk
# Processing Record 46 of Set 7 | west fargo
# Processing Record 47 of Set 7 | uk
# City not found. Skipping...
# Processing Record 48 of Set 7 | redmond
# Processing Record 49 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 7 | taveta
# Processing Record 1 of Set 8 | vila
# Processing Record 2 of Set 8 | katsuura
# Processing Record 3 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 8 | bermeo
# Processing Record 5 of Set 8 | umuarama
# Processing Record 6 of Set 8 | anito
# Processing Record 7 of Set 8 | bozhou
# Processing Record 8 of Set 8 | aswan
# Processing Record 9 of Set 8 | bambanglipuro
# Processing Record 10 of Set 8 | beloha
# Processing Record 11 of Set 8 | pokaran
# Processing Record 12 of Set 8 | talaya
# Processing Record 13 of Set 8 | maralal
# Processing Record 14 of Set 8 | yantal
# Processing Record 15 of Set 8 | torbay
# Processing Record 16 of Set 8 | madang
# Processing Record 17 of Set 8 | mao
# Processing Record 18 of Set 8 | arona
# Processing Record 19 of Set 8 | amurzet
# Processing Record 20 of Set 8 | humaita
# Processing Record 21 of Set 8 | velykoploske
# Processing Record 22 of Set 8 | indian head
# Processing Record 23 of Set 8 | matara
# Processing Record 24 of Set 8 | morondava
# Processing Record 25 of Set 8 | bundaberg
# Processing Record 26 of Set 8 | gemena
# Processing Record 27 of Set 8 | hamilton
# Processing Record 28 of Set 8 | saltillo
# Processing Record 29 of Set 8 | santa maria
# Processing Record 30 of Set 8 | tiznit
# Processing Record 31 of Set 8 | tapiramuta
# Processing Record 32 of Set 8 | raudeberg
# Processing Record 33 of Set 8 | kharan
# Processing Record 34 of Set 8 | luganville
# Processing Record 35 of Set 8 | cockburn town
# Processing Record 36 of Set 8 | kyshtovka
# Processing Record 37 of Set 8 | gat
# Processing Record 38 of Set 8 | chuy
# Processing Record 39 of Set 8 | makakilo city
# Processing Record 40 of Set 8 | urengoy
# Processing Record 41 of Set 8 | tuktoyaktuk
# Processing Record 42 of Set 8 | ahuimanu
# Processing Record 43 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 8 | acurenam
# Processing Record 45 of Set 8 | amaigbo
# Processing Record 46 of Set 8 | batemans bay
# Processing Record 47 of Set 8 | vetlanda
# Processing Record 48 of Set 8 | ganzhou
# Processing Record 49 of Set 8 | darhan
# Processing Record 50 of Set 8 | ilulissat
# Processing Record 1 of Set 9 | sao filipe
# Processing Record 2 of Set 9 | save
# Processing Record 3 of Set 9 | hami
# Processing Record 4 of Set 9 | hare bay
# Processing Record 5 of Set 9 | kaeo
# Processing Record 6 of Set 9 | saint-pacome
# City not found. Skipping...
# Processing Record 7 of Set 9 | urumqi
# Processing Record 8 of Set 9 | bundu
# Processing Record 9 of Set 9 | aksu
# Processing Record 10 of Set 9 | ituacu
# Processing Record 11 of Set 9 | felanitx
# Processing Record 12 of Set 9 | ravar
# Processing Record 13 of Set 9 | wajima
# Processing Record 14 of Set 9 | wangaratta
# Processing Record 15 of Set 9 | luderitz
# Processing Record 16 of Set 9 | puerto baquerizo moreno
# Processing Record 17 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 18 of Set 9 | apsheronsk
# Processing Record 19 of Set 9 | autazes
# Processing Record 20 of Set 9 | olafsvik
# Processing Record 21 of Set 9 | cochabamba
# Processing Record 22 of Set 9 | mayumba
# Processing Record 23 of Set 9 | avdon
# Processing Record 24 of Set 9 | gisborne
# Processing Record 25 of Set 9 | quatre cocos
# Processing Record 26 of Set 9 | cerignola
# Processing Record 27 of Set 9 | palana
# Processing Record 28 of Set 9 | yueyang
# Processing Record 29 of Set 9 | sao felix do xingu
# Processing Record 30 of Set 9 | west bay
# Processing Record 31 of Set 9 | maniitsoq
# Processing Record 32 of Set 9 | bardiyah
# Processing Record 33 of Set 9 | takoradi
# Processing Record 34 of Set 9 | ballina
# Processing Record 35 of Set 9 | springdale
# Processing Record 36 of Set 9 | cartagena
# Processing Record 37 of Set 9 | nome
# Processing Record 38 of Set 9 | udachnyy
# Processing Record 39 of Set 9 | dwarka
# Processing Record 40 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 9 | okhotsk
# Processing Record 42 of Set 9 | solnechnyy
# Processing Record 43 of Set 9 | nanlong
# Processing Record 44 of Set 9 | filingue
# Processing Record 45 of Set 9 | sambava
# Processing Record 46 of Set 9 | filotion
# Processing Record 47 of Set 9 | huarmey
# Processing Record 48 of Set 9 | muros
# Processing Record 49 of Set 9 | caruray
# Processing Record 50 of Set 9 | grindavik
# Processing Record 1 of Set 10 | havoysund
# Processing Record 2 of Set 10 | belfast
# Processing Record 3 of Set 10 | nioro
# Processing Record 4 of Set 10 | ucluelet
# Processing Record 5 of Set 10 | nuuk
# Processing Record 6 of Set 10 | kulai
# Processing Record 7 of Set 10 | tursunzoda
# Processing Record 8 of Set 10 | zile
# Processing Record 9 of Set 10 | chernyshevsk
# Processing Record 10 of Set 10 | talara
# Processing Record 11 of Set 10 | saldanha
# Processing Record 12 of Set 10 | wuzhou
# Processing Record 13 of Set 10 | mpika
# Processing Record 14 of Set 10 | benguela
# Processing Record 15 of Set 10 | araguacu
# Processing Record 16 of Set 10 | hobyo
# Processing Record 17 of Set 10 | shitkino
# Processing Record 18 of Set 10 | avarua
# Processing Record 19 of Set 10 | impfondo
# Processing Record 20 of Set 10 | leningradskiy
# Processing Record 21 of Set 10 | pontianak
# Processing Record 22 of Set 10 | listvyanka
# Processing Record 23 of Set 10 | oneonta
# Processing Record 24 of Set 10 | kongolo
# Processing Record 25 of Set 10 | wattegama
# Processing Record 26 of Set 10 | san jose
# Processing Record 27 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 10 | la reforma
# Processing Record 29 of Set 10 | marfino
# Processing Record 30 of Set 10 | innisfail
# Processing Record 31 of Set 10 | batagay-alyta
# Processing Record 32 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 10 | la plata
# Processing Record 34 of Set 10 | lazne bohdanec
# Processing Record 35 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 10 | te anau
# Processing Record 37 of Set 10 | antalaha
# Processing Record 38 of Set 10 | langxiang
# Processing Record 39 of Set 10 | songjianghe
# Processing Record 40 of Set 10 | lincoln
# Processing Record 41 of Set 10 | moura
# Processing Record 42 of Set 10 | puerto escondido
# Processing Record 43 of Set 10 | sioux lookout
# Processing Record 44 of Set 10 | zeya
# Processing Record 45 of Set 10 | maldonado
# Processing Record 46 of Set 10 | tilichiki
# Processing Record 47 of Set 10 | belaya gora
# Processing Record 48 of Set 10 | sena madureira
# Processing Record 49 of Set 10 | aksarka
# Processing Record 50 of Set 10 | kiunga
# Processing Record 1 of Set 11 | brufut
# Processing Record 2 of Set 11 | andenes
# Processing Record 3 of Set 11 | woodward
# Processing Record 4 of Set 11 | rubizhne
# Processing Record 5 of Set 11 | amapa
# Processing Record 6 of Set 11 | fort nelson
# Processing Record 7 of Set 11 | kati
# Processing Record 8 of Set 11 | buraydah
# Processing Record 9 of Set 11 | akyab
# Processing Record 10 of Set 11 | mlowo
# Processing Record 11 of Set 11 | faanui
# Processing Record 12 of Set 11 | trapani
# Processing Record 13 of Set 11 | kalmunai
# Processing Record 14 of Set 11 | mingaora
# Processing Record 15 of Set 11 | xiongzhou
# Processing Record 16 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 17 of Set 11 | marondera
# Processing Record 18 of Set 11 | borger
# Processing Record 19 of Set 11 | coahuayana
# Processing Record 20 of Set 11 | tha bo
# Processing Record 21 of Set 11 | sakakah
# Processing Record 22 of Set 11 | borgarnes
# Processing Record 23 of Set 11 | buala
# Processing Record 24 of Set 11 | biak
# Processing Record 25 of Set 11 | la palma
# Processing Record 26 of Set 11 | conde
# Processing Record 27 of Set 11 | mariveles
# Processing Record 28 of Set 11 | owando
# Processing Record 29 of Set 11 | plettenberg bay
# Processing Record 30 of Set 11 | mount isa
# Processing Record 31 of Set 11 | vallenar
# Processing Record 32 of Set 11 | fomboni
# Processing Record 33 of Set 11 | gamba
# Processing Record 34 of Set 11 | kushima
# Processing Record 35 of Set 11 | sept-iles
# Processing Record 36 of Set 11 | nanchong
# Processing Record 37 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 11 | asau
# Processing Record 39 of Set 11 | itoman
# Processing Record 40 of Set 11 | sun valley
# Processing Record 41 of Set 11 | kuching
# Processing Record 42 of Set 11 | betlitsa
# Processing Record 43 of Set 11 | clyde river
# Processing Record 44 of Set 11 | mahajanga
# Processing Record 45 of Set 11 | loandjili
# Processing Record 46 of Set 11 | ramban
# Processing Record 47 of Set 11 | pocone
# Processing Record 48 of Set 11 | florence
# Processing Record 49 of Set 11 | shingu
# Processing Record 50 of Set 11 | port hueneme
# Processing Record 1 of Set 12 | puerto del rosario
# Processing Record 2 of Set 12 | portland
# Processing Record 3 of Set 12 | burns lake
# Processing Record 4 of Set 12 | bilibino
# Processing Record 5 of Set 12 | estreito
# Processing Record 6 of Set 12 | machala
# Processing Record 7 of Set 12 | goundi
# Processing Record 8 of Set 12 | sorland
# Processing Record 9 of Set 12 | mahebourg
# Processing Record 10 of Set 12 | porto novo
# Processing Record 11 of Set 12 | ciudad bolivar
# Processing Record 12 of Set 12 | hambantota
# Processing Record 13 of Set 12 | tautira
# Processing Record 14 of Set 12 | mayahi
# Processing Record 15 of Set 12 | bagasara
# City not found. Skipping...
# Processing Record 16 of Set 12 | santiago de cao
# Processing Record 17 of Set 12 | hofn
# Processing Record 18 of Set 12 | dossor
# Processing Record 19 of Set 12 | vuktyl
# Processing Record 20 of Set 12 | ayolas
# Processing Record 21 of Set 12 | nguru
# Processing Record 22 of Set 12 | pandamatenga
# Processing Record 23 of Set 12 | itacare
# Processing Record 24 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 12 | puerto parra
# Processing Record 26 of Set 12 | mpulungu
# Processing Record 27 of Set 12 | mbacke
# City not found. Skipping...
# Processing Record 28 of Set 12 | watrous
# Processing Record 29 of Set 12 | bilma
# Processing Record 30 of Set 12 | honiara
# Processing Record 31 of Set 12 | altamira
# Processing Record 32 of Set 12 | namibe
# Processing Record 33 of Set 12 | oudtshoorn
# Processing Record 34 of Set 12 | kirakira
# Processing Record 35 of Set 12 | druzhba
# Processing Record 36 of Set 12 | hurghada
# Processing Record 37 of Set 12 | kurumkan
# Processing Record 38 of Set 12 | ola
# Processing Record 39 of Set 12 | thinadhoo
# Processing Record 40 of Set 12 | mitsamiouli
# Processing Record 41 of Set 12 | uglegorsk
# Processing Record 42 of Set 12 | qasigiannguit
# Processing Record 43 of Set 12 | camacha
# Processing Record 44 of Set 12 | kuala terengganu
# Processing Record 45 of Set 12 | vila velha
# Processing Record 46 of Set 12 | sandnessjoen
# Processing Record 47 of Set 12 | minsk
# Processing Record 48 of Set 12 | monterey
# Processing Record 49 of Set 12 | bahia blanca
# Processing Record 50 of Set 12 | la romana
# Processing Record 1 of Set 13 | racine
# Processing Record 2 of Set 13 | tianjin
# Processing Record 3 of Set 13 | lima
# Processing Record 4 of Set 13 | russell
# Processing Record 5 of Set 13 | hillsboro
# Processing Record 6 of Set 13 | araouane
# Processing Record 7 of Set 13 | mananjary
# Processing Record 8 of Set 13 | tual
# Processing Record 9 of Set 13 | yatou
# Processing Record 10 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 13 | wajid
# Processing Record 12 of Set 13 | kulhudhuffushi
# Processing Record 13 of Set 13 | pangnirtung
# Processing Record 14 of Set 13 | cua
# Processing Record 15 of Set 13 | prainha
# Processing Record 16 of Set 13 | inegol
# Processing Record 17 of Set 13 | sangar
# Processing Record 18 of Set 13 | karwar
# Processing Record 19 of Set 13 | ottersberg
# Processing Record 20 of Set 13 | kabompo
# Processing Record 21 of Set 13 | bud
# Processing Record 22 of Set 13 | tacoronte
# Processing Record 23 of Set 13 | saint-denis
# Processing Record 24 of Set 13 | niort
# Processing Record 25 of Set 13 | umea
# Processing Record 26 of Set 13 | asfi
# Processing Record 27 of Set 13 | wahpeton
# Processing Record 28 of Set 13 | nantucket
# Processing Record 29 of Set 13 | izmir
# Processing Record 30 of Set 13 | irituia
# Processing Record 31 of Set 13 | maningrida
# Processing Record 32 of Set 13 | jiuquan
# Processing Record 33 of Set 13 | elat
# Processing Record 34 of Set 13 | mizdah
# Processing Record 35 of Set 13 | miquelon
# Processing Record 36 of Set 13 | pointe michel
# Processing Record 37 of Set 13 | beira
# Processing Record 38 of Set 13 | panama city
# Processing Record 39 of Set 13 | umuahia
# Processing Record 40 of Set 13 | haines junction
# Processing Record 41 of Set 13 | jining
# Processing Record 42 of Set 13 | traralgon
# Processing Record 43 of Set 13 | ternate
# Processing Record 44 of Set 13 | omboue
# Processing Record 45 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 46 of Set 13 | chokurdakh
# Processing Record 47 of Set 13 | bireun
# Processing Record 48 of Set 13 | amuntai
# Processing Record 49 of Set 13 | guasdualito
# Processing Record 50 of Set 13 | japura
# Processing Record 1 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 14 | astoria
# Processing Record 3 of Set 14 | grand gaube
# Processing Record 4 of Set 14 | shakiso
# Processing Record 5 of Set 14 | price
# Processing Record 6 of Set 14 | taoudenni
# Processing Record 7 of Set 14 | chala
# Processing Record 8 of Set 14 | koudougou
# Processing Record 9 of Set 14 | acapulco
# Processing Record 10 of Set 14 | amontada
# Processing Record 11 of Set 14 | zonguldak
# Processing Record 12 of Set 14 | fredericksburg
# Processing Record 13 of Set 14 | miri
# Processing Record 14 of Set 14 | mendota
# Processing Record 15 of Set 14 | harper
# Processing Record 16 of Set 14 | kpandae
# Processing Record 17 of Set 14 | masuguru
# Processing Record 18 of Set 14 | lovington
# Processing Record 19 of Set 14 | tommot
# Processing Record 20 of Set 14 | casablanca
# Processing Record 21 of Set 14 | skjervoy
# Processing Record 22 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 23 of Set 14 | linjiang
# Processing Record 24 of Set 14 | great yarmouth
# Processing Record 25 of Set 14 | riviere-au-renard
# Processing Record 26 of Set 14 | santiago del estero
# Processing Record 27 of Set 14 | kloulklubed
# Processing Record 28 of Set 14 | gorontalo
# Processing Record 29 of Set 14 | vargata
# Processing Record 30 of Set 14 | champasak
# Processing Record 31 of Set 14 | twentynine palms
# Processing Record 32 of Set 14 | north branch
# Processing Record 33 of Set 14 | ilhabela
# Processing Record 34 of Set 14 | leh
# Processing Record 35 of Set 14 | nyagan
# Processing Record 36 of Set 14 | saint-francois
# Processing Record 37 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 14 | watertown
# Processing Record 39 of Set 14 | port-gentil
# Processing Record 40 of Set 14 | lata
# Processing Record 41 of Set 14 | novokayakent
# Processing Record 42 of Set 14 | antigonish
# Processing Record 43 of Set 14 | port hardy
# Processing Record 44 of Set 14 | henties bay
# Processing Record 45 of Set 14 | diapaga
# Processing Record 46 of Set 14 | palmer
# Processing Record 47 of Set 14 | bonavista
# Processing Record 48 of Set 14 | zyryanka
# Processing Record 49 of Set 14 | goiana
# Processing Record 50 of Set 14 | kizukuri
# Processing Record 1 of Set 15 | naryan-mar
# Processing Record 2 of Set 15 | eydhafushi
# Processing Record 3 of Set 15 | awbari
# Processing Record 4 of Set 15 | bereda
# Processing Record 5 of Set 15 | katobu
# Processing Record 6 of Set 15 | kazanskoye
# Processing Record 7 of Set 15 | lubao
# Processing Record 8 of Set 15 | zatoka
# Processing Record 9 of Set 15 | bay roberts
# Processing Record 10 of Set 15 | burica
# City not found. Skipping...
# Processing Record 11 of Set 15 | belyy yar
# Processing Record 12 of Set 15 | along
# Processing Record 13 of Set 15 | orocue
# Processing Record 14 of Set 15 | shenkursk
# Processing Record 15 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 15 | bathsheba
# Processing Record 17 of Set 15 | pedernales
# Processing Record 18 of Set 15 | miracema do tocantins
# Processing Record 19 of Set 15 | dali
# Processing Record 20 of Set 15 | laguna
# Processing Record 21 of Set 15 | wolomin
# Processing Record 22 of Set 15 | alofi
# Processing Record 23 of Set 15 | nicoya
# Processing Record 24 of Set 15 | amahai
# Processing Record 25 of Set 15 | olinda
# Processing Record 26 of Set 15 | montalto uffugo
# Processing Record 27 of Set 15 | angul
# Processing Record 28 of Set 15 | maceio
# Processing Record 29 of Set 15 | formosa
# Processing Record 30 of Set 15 | awka
# Processing Record 31 of Set 15 | ordzhonikidze
# Processing Record 32 of Set 15 | guiberoua
# Processing Record 33 of Set 15 | broome
# Processing Record 34 of Set 15 | champerico
# Processing Record 35 of Set 15 | galesong
# Processing Record 36 of Set 15 | arbroath
# Processing Record 37 of Set 15 | xifeng
# Processing Record 38 of Set 15 | rexburg
# Processing Record 39 of Set 15 | formosa do rio preto
# Processing Record 40 of Set 15 | belmonte
# Processing Record 41 of Set 15 | iskateley
# Processing Record 42 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 15 | fort myers beach
# Processing Record 44 of Set 15 | robe
# Processing Record 45 of Set 15 | amga
# Processing Record 46 of Set 15 | tambura
# Processing Record 47 of Set 15 | thabazimbi
# Processing Record 48 of Set 15 | pereslavl-zalesskiy
# Processing Record 49 of Set 15 | yerbogachen
# Processing Record 50 of Set 15 | kano
# Processing Record 1 of Set 16 | lenki
# City not found. Skipping...
# Processing Record 2 of Set 16 | baruun-urt
# Processing Record 3 of Set 16 | otane
# Processing Record 4 of Set 16 | pasni
# Processing Record 5 of Set 16 | ilo
# Processing Record 6 of Set 16 | wajir
# Processing Record 7 of Set 16 | sao joao da barra
# Processing Record 8 of Set 16 | camana
# Processing Record 9 of Set 16 | sorong
# Processing Record 10 of Set 16 | nouadhibou
# Processing Record 11 of Set 16 | bagan
# Processing Record 12 of Set 16 | pacific grove
# Processing Record 13 of Set 16 | boyolangu
# Processing Record 14 of Set 16 | guane
# Processing Record 15 of Set 16 | zakamensk
# Processing Record 16 of Set 16 | isla mujeres
# Processing Record 17 of Set 16 | canyon lake
# Processing Record 18 of Set 16 | wanlaweyn
# Processing Record 19 of Set 16 | najran
# Processing Record 20 of Set 16 | rumphi
# Processing Record 21 of Set 16 | margate
# Processing Record 22 of Set 16 | dien bien
# City not found. Skipping...
# Processing Record 23 of Set 16 | ambulu
# Processing Record 24 of Set 16 | nehoiu
# Processing Record 25 of Set 16 | union
# Processing Record 26 of Set 16 | fortuna
# Processing Record 27 of Set 16 | zhigansk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Nikolskoye      RU  59.7035   30.7861     70.88        56          94
# 1     Batticaloa      LK   7.7102   81.6924     82.44        74         100
# 2        Labuhan      ID  -6.8844  112.2051     79.25        77          55
# 3       Bengkulu      ID  -3.8004  102.2655     79.16        83          87
# 4     San Andres      CO  12.5847  -81.7006     84.22        79          40
# 5  Srednekolymsk      RU  67.4500  153.6833     43.86        72           8
# 6   Punta Arenas      CL -53.1500  -70.9167     41.11        87         100
# 7          Bluff      NZ -46.6000  168.3333     47.80        77         100
# 8      Jamestown      US  42.0970  -79.2353     76.17        72         100
# 9         Taltal      CL -25.4000  -70.4833     63.37        65          65
#
#    Wind Speed Current Description
# 0        6.82     overcast clouds
# 1        4.54       moderate rain
# 2        9.06       broken clouds
# 3        2.75     overcast clouds
# 4        9.22    scattered clouds
# 5       12.44           clear sky
# 6       23.02       moderate rain
# 7       10.74     overcast clouds
# 8       16.11     overcast clouds
# 9        5.97       broken clouds

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
